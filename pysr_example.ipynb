# %% [markdown]
# From https://github.com/MilesCranmer/PySR/tree/master/examples

# %%
import pysr
import sympy
import numpy as np
from matplotlib import pyplot as plt
from pysr import PySRRegressor
from sklearn.model_selection import train_test_split
# Out:
# Detected IPython. Loading juliacall extension. See https://juliapy.github.io/PythonCall.jl/stable/compat/#IPython

# %%
# Dataset
np.random.seed(0)
X = 2 * np.random.randn(100, 5) #100 by 5 array of samples from normal distribution with mean 0 and std of 2
y = 2.5382 * np.cos(X[:, 3]) + X[:, 0] ** 2 - 2

# %%
default_pysr_params = dict(
    populations=30,
    model_selection="best",
)

# %%
# Learn equations
model = PySRRegressor(
    niterations=30, #set total number of cycles of evolution
    binary_operators=["+", "*"],
    unary_operators=["cos", "exp", "sin"],
    **default_pysr_params,
)

model.fit(X, y)
# Out:
# /home/grads/miniconda/envs/megan/lib/python3.9/site-packages/pysr/sr.py:2811: UserWarning: Note: it looks like you are running in Jupyter. The progress bar will be turned off.
#   warnings.warn(
# Compiling Julia backend...
# [ Info: Started!
# Expressions evaluated per second: 1.220e+05
# Progress: 653 / 900 total iterations (72.556%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           3.360e+01  0.000e+00  y = 2.3552
# 3           6.128e+00  8.509e-01  y = x₀ * x₀
# 5           3.045e+00  3.496e-01  y = (x₀ * x₀) + -1.7558
# 7           3.030e+00  2.620e-03  y = (x₀ * (x₀ * 0.97769)) + -1.6641
# 8           1.118e+00  9.964e-01  y = (cos(x₃) + -1.852) + (x₀ * x₀)
# 10          2.543e-13  1.456e+01  y = (x₀ * x₀) + ((2.5382 * cos(x₃)) + -2)
# 12          1.680e-13  2.073e-01  y = (cos(x₃) + ((x₀ * (x₀ * 0.39398)) + -0.78796)) * 2.538...
#                                       2
# 14          1.606e-13  2.255e-02  y = (((((x₀ * 0.39398) * x₀) + -1.4967) + cos(x₃)) + 0.708...
#                                       79) * 2.5382
# 16          1.495e-13  3.598e-02  y = (((cos(x₃) * 0.29096) + ((x₀ * (x₀ * 0.11463)) + -0.19...
#                                       759)) * 8.7234) + -0.27631
# 19          1.435e-13  1.348e-02  y = ((cos(x₃) + ((cos(x₃) * -0.18702) + ((x₀ * (x₀ * 0.320...
#                                       3)) + -0.58892))) * 3.1221) + -0.16133
# 26          1.101e-13  3.787e-02  y = (x₀ * (x₀ * 0.11023)) + ((((x₀ * 0.44054) + ((x₀ * 0.0...
#                                       39846) + (x₀ * 0.40938))) * x₀) + ((cos(x₃) * 2.5382) + -2...
#                                       ))
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
# [ Info: Final population:
# [ Info: Results saved to:
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           3.360e+01  0.000e+00  y = 2.3552
# 3           6.128e+00  8.509e-01  y = x₀ * x₀
# 5           3.045e+00  3.496e-01  y = (x₀ * x₀) + -1.7558
# 7           3.030e+00  2.620e-03  y = (x₀ * (x₀ * 0.97769)) + -1.6641
# 8           1.118e+00  9.964e-01  y = (cos(x₃) + -1.852) + (x₀ * x₀)
# 9           9.515e-01  1.617e-01  y = (exp(cos(x₃)) + (x₀ * x₀)) + -3.1191
# 10          2.265e-13  2.907e+01  y = ((cos(x₃) * 2.5382) + -2) + (x₀ * x₀)
# 12          1.680e-13  1.493e-01  y = (cos(x₃) + ((x₀ * (x₀ * 0.39398)) + -0.78796)) * 2.538...
#                                       2
# 14          1.566e-13  3.514e-02  y = ((cos(x₃) + (((x₀ * x₀) + -0.20738) * 0.39398)) + -0.7...
#                                       0626) * 2.5382
# 16          1.495e-13  2.340e-02  y = (((cos(x₃) * 0.29096) + ((x₀ * (x₀ * 0.11463)) + -0.19...
#                                       759)) * 8.7234) + -0.27631
# 18          1.069e-13  1.675e-01  y = (((x₀ * 0.46448) * x₀) + (x₀ * (x₀ * 0.53552))) + ((co...
#                                       s(x₃) * 2.5382) + -2)
# 29          8.935e-14  1.631e-02  y = (((x₀ * 0.12351) * x₀) + ((x₀ * (((((x₀ + sin(x₀)) * -...
#                                       5.623e-08) + x₀) * 0.42266) + (x₀ * 0.45382))) + (cos(x₃) ...
#                                       * 2.5382))) + -2
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# PySRRegressor.equations_ = [
# 	    pick      score                                           equation  \
# 	0          0.000000                                          2.3552148
# 	1          0.850855                                            x0 * x0
# 	2          0.349618                             (x0 * x0) + -1.7557528
# 	3          0.002620              (x0 * (x0 * 0.97769207)) + -1.6640593
# 	4          0.996444                 (cos(x3) + -1.8519864) + (x0 * x0)
# 	5          0.161678              (exp(cos(x3)) + (x0 * x0)) + -3.11913
# 	6         29.066350            ((cos(x3) * 2.5382) + -2.0) + (x0 * x0)
# 	7          0.149288  (cos(x3) + ((x0 * (x0 * 0.39397997)) + -0.7879...
# 	8          0.035138  ((cos(x3) + (((x0 * x0) + -0.20738119) * 0.393...
# 	9          0.023397  (((cos(x3) * 0.29096374) + ((x0 * (x0 * 0.1146...
# 	10  >>>>   0.167539  (((x0 * 0.46448296) * x0) + (x0 * (x0 * 0.5355...
# 	11         0.016308  (((x0 * 0.12351309) * x0) + ((x0 * (((((x0 + s...
#
# 	            loss  complexity
# 	0   3.360272e+01           1
# 	1   6.128180e+00           3
# 	2   3.045492e+00           5
# 	3   3.029573e+00           7
# 	4   1.118488e+00           8
# 	5   9.515150e-01           9
# 	6   2.264958e-13          10
# 	7   1.680312e-13          12
# 	8   1.566279e-13          14
# 	9   1.494674e-13          16
# 	10  1.069115e-13          18
# 	11  8.935439e-14          29
# ]
#   - outputs/20250602_124107_sXKIXz/hall_of_fame.csv

# %%
model
# Out:
# PySRRegressor.equations_ = [
# 	    pick      score                                           equation  \
# 	0          0.000000                                          2.3552148
# 	1          0.850855                                            x0 * x0
# 	2          0.349618                             (x0 * x0) + -1.7557528
# 	3          0.002620              (x0 * (x0 * 0.97769207)) + -1.6640593
# 	4          0.996444                 (cos(x3) + -1.8519864) + (x0 * x0)
# 	5          0.161678              (exp(cos(x3)) + (x0 * x0)) + -3.11913
# 	6         29.066350            ((cos(x3) * 2.5382) + -2.0) + (x0 * x0)
# 	7          0.149288  (cos(x3) + ((x0 * (x0 * 0.39397997)) + -0.7879...
# 	8          0.035138  ((cos(x3) + (((x0 * x0) + -0.20738119) * 0.393...
# 	9          0.023397  (((cos(x3) * 0.29096374) + ((x0 * (x0 * 0.1146...
# 	10  >>>>   0.167539  (((x0 * 0.46448296) * x0) + (x0 * (x0 * 0.5355...
# 	11         0.016308  (((x0 * 0.12351309) * x0) + ((x0 * (((((x0 + s...
#
# 	            loss  complexity
# 	0   3.360272e+01           1
# 	1   6.128180e+00           3
# 	2   3.045492e+00           5
# 	3   3.029573e+00           7
# 	4   1.118488e+00           8
# 	5   9.515150e-01           9
# 	6   2.264958e-13          10
# 	7   1.680312e-13          12
# 	8   1.566279e-13          14
# 	9   1.494674e-13          16
# 	10  1.069115e-13          18
# 	11  8.935439e-14          29
# ]

# %%
model.sympy() #view best expression
# Out:
# x0*0.46448296*x0 + x0*x0*0.53551704 + cos(x3)*2.5382 - 2.0

# %%
model.sympy(2) #view another expression in list using index
# Out:
# x0*x0 - 1.7557528

# %%
model.equations_  #this is a pandas dataframe
# Out:
#     complexity          loss  \
# 0            1  3.360272e+01
# 1            3  6.128180e+00
# 2            5  3.045492e+00
# 3            7  3.029573e+00
# 4            8  1.118488e+00
# 5            9  9.515150e-01
# 6           10  2.264958e-13
# 7           12  1.680312e-13
# 8           14  1.566279e-13
# 9           16  1.494674e-13
# 10          18  1.069115e-13
# 11          29  8.935439e-14
#
#                                              equation      score  \
# 0                                           2.3552148   0.000000
# 1                                             x0 * x0   0.850855
# 2                              (x0 * x0) + -1.7557528   0.349618
# 3               (x0 * (x0 * 0.97769207)) + -1.6640593   0.002620
# 4                  (cos(x3) + -1.8519864) + (x0 * x0)   0.996444
# 5               (exp(cos(x3)) + (x0 * x0)) + -3.11913   0.161678
# 6             ((cos(x3) * 2.5382) + -2.0) + (x0 * x0)  29.066350
# 7   (cos(x3) + ((x0 * (x0 * 0.39397997)) + -0.7879...   0.149288
# 8   ((cos(x3) + (((x0 * x0) + -0.20738119) * 0.393...   0.035138
# 9   (((cos(x3) * 0.29096374) + ((x0 * (x0 * 0.1146...   0.023397
# 10  (((x0 * 0.46448296) * x0) + (x0 * (x0 * 0.5355...   0.167539
# 11  (((x0 * 0.12351309) * x0) + ((x0 * (((((x0 + s...   0.016308
#
#                                          sympy_format  \
# 0                                    2.35521480000000
# 1                                               x0*x0
# 2                                   x0*x0 - 1.7557528
# 3                        x0*x0*0.97769207 - 1.6640593
# 4                         x0*x0 + cos(x3) - 1.8519864
# 5                      x0*x0 + exp(cos(x3)) - 3.11913
# 6                        x0*x0 + cos(x3)*2.5382 - 2.0
# 7   (x0*x0*0.39397997 + cos(x3) - 0.78795993)*2.53...
# 8   ((x0*x0 - 0.20738119)*0.39398 + cos(x3) - 0.70...
# 9   (x0*x0*0.114633895 + cos(x3)*0.29096374 - 0.19...
# 10  x0*0.46448296*x0 + x0*x0*0.53551704 + cos(x3)*...
# 11  x0*(x0*0.453825 + (x0 + (x0 + sin(x0))*(-5.623...
#
#                                         lambda_format
# 0                   PySRFunction(X=>2.35521480000000)
# 1                              PySRFunction(X=>x0*x0)
# 2                  PySRFunction(X=>x0*x0 - 1.7557528)
# 3       PySRFunction(X=>x0*x0*0.97769207 - 1.6640593)
# 4        PySRFunction(X=>x0*x0 + cos(x3) - 1.8519864)
# 5     PySRFunction(X=>x0*x0 + exp(cos(x3)) - 3.11913)
# 6       PySRFunction(X=>x0*x0 + cos(x3)*2.5382 - 2.0)
# 7   PySRFunction(X=>(x0*x0*0.39397997 + cos(x3) - ...
# 8   PySRFunction(X=>((x0*x0 - 0.20738119)*0.39398 ...
# 9   PySRFunction(X=>(x0*x0*0.114633895 + cos(x3)*0...
# 10  PySRFunction(X=>x0*0.46448296*x0 + x0*x0*0.535...
# 11  PySRFunction(X=>x0*(x0*0.453825 + (x0 + (x0 + ...

# %%
model.latex() #can also use model.jax(), model.pytorch()
# Out:
# 'x_{0} \\cdot 0.464 x_{0} + x_{0} x_{0} \\cdot 0.536 + \\cos{\\left(x_{3} \\right)} 2.54 - 2.00'

# %%
ypredict = model.predict(X)
ypredict_simpler = model.predict(X, 2)

print("Default selection MSE:", np.power(ypredict - y, 2).mean())
print("Manual selection MSE for index 2:", np.power(ypredict_simpler - y, 2).mean())
# Out:
# Default selection MSE: 3.6780639705929675e-31
# Manual selection MSE for index 2: 3.0454920139385084
