# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
i = 0 #note: 0 is the training loss and 1 is the validation loss

# %%
high32 = np.loadtxt("losses_32high.txt")[0]
low32 = np.loadtxt("losses_32low.txt")[0]
x = list(range(0,len(baseline)))

# %%
plt.plot(x, high32, label = "High (32)", color = "black")
plt.plot(x, low32, label = "Low (32)", color = "black")

plt.xlabel("Epoch")
plt.ylabel("Training Loss")
plt.legend()
plt.yscale("log")
plt.title("Effect of Squeezing Covariance Matrix")
plt.show()
