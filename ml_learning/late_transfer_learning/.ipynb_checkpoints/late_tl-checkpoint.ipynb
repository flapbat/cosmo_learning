# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
dashList = [(5,2),(2,5),(4,10),(3,3,2,2),(5,2,20,2)]

# %%
i = 0 #note: 0 is the training loss and 1 is the validation loss

# %%
baseline_losses = np.loadtxt("losses_none.txt")[0]
late1_losses = np.loadtxt("losses_late1.txt")[0]
late2_losses = np.loadtxt("losses_late2.txt")[0]
late3_losses = np.loadtxt("losses_late2.txt")[0]
x = list(range(0,len(baseline_losses)))

# %%
#linestyles : https://matplotlib.org/stable/gallery/lines_bars_and_markers/linestyles.html
plt.plot(x, baseline_losses, label = "Baseline", color = "black")
plt.plot(x, late1_losses, label = "Late 1", linestyle='dotted' )
plt.plot(x, late2_losses, label = "Late 2", linestyle='dashed')
plt.xlabel("Epoch")
plt.ylabel("Training Loss")
plt.legend()
plt.yscale("log")
plt.show()
