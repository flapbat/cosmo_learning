# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
i = 0 #note: 0 is the training loss and 1 is the validation loss

# %%
baseline = np.loadtxt("chi2_baseline.txt").T
x = list(range(0,len(baseline[0])))

# %%
def get_data(filename):
    return np.loadtxt(filename)[i]

# %%
plt.plot(x, baseline[0], label = "Mean Chi2")
plt.plot(x, baseline[1], label = "Median Chi2")
#plt.plot(list(range(0,len(epoch200))), epoch200, label = "Number of epochs = 200")
#plt.plot(list(range(0,len(epoch300))), epoch300, label = "Number of epochs = 300")
plt.xlabel("Epoch")
#plt.ylabel("Training Loss")
plt.legend()
plt.yscale("log")
plt.title("Effect of Number of Epochs")
plt.show()

# %%
plt.plot(x, baseline[2], label = "Chi2 > 1")
plt.plot(x, baseline[3], label = "Chi2 > 0.2")
#plt.plot(list(range(0,len(epoch200))), epoch200, label = "Number of epochs = 200")
#plt.plot(list(range(0,len(epoch300))), epoch300, label = "Number of epochs = 300")
plt.xlabel("Epoch")
#plt.ylabel("Training Loss")
plt.legend()
#plt.yscale("log")
plt.title("Effect of Number of Epochs")
plt.show()

# %%
plt.plot(x, baseline, label = "Learning Rate = 1e-3", color = "black")
plt.plot(x, lr2, label = "Learning Rate = 1e-2")
plt.plot(x, lr4, label = "Learning Rate = 1e-4")
plt.xlabel("Epoch")
plt.ylabel("Training Loss")
plt.legend()
plt.yscale("log")
plt.title("Effect of Learning Rate")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[15], line 2
#       1 plt.plot(x, baseline, label = "Learning Rate = 1e-3", color = "black")
# ----> 2 plt.plot(x, lr2, label = "Learning Rate = 1e-2")
#       3 plt.plot(x, lr4, label = "Learning Rate = 1e-4")
#       4 plt.xlabel("Epoch")
#
# NameError: name 'lr2' is not defined

# %%
plt.plot(x, baseline, label = "Weight decay = 0", color = "black")
plt.plot(x, weightm1, label = "Weight decay = -1")
plt.plot(x, weight1, label = "Weight decay = 1")
plt.xlabel("Epoch")
plt.ylabel("Training Loss")
plt.legend()
plt.yscale("log")
plt.title("Effect of Weight Decay")
plt.show()
